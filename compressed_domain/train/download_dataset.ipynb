# %%
import kagglehub
import shutil
from pathlib import Path

# %%
base = Path("/tmp/msrvtt")
video_dir = base / "videos"
caption_dir = base / "captions"

video_dir.mkdir(parents=True, exist_ok=True)
caption_dir.mkdir(parents=True, exist_ok=True)

video_path = kagglehub.dataset_download(
    "vishnutheepb/msrvtt",
    output_dir=str(video_dir)
)

caption_path = kagglehub.dataset_download(
    "vishnutheepb/msrvttdatainfo",
    output_dir=str(caption_dir)
)

print("Videos:", video_path)
print("Captions:", caption_path)
# Out:
# Downloading to /tmp/msrvtt/videos/1.archive...
# 100%|██████████| 4.26G/4.26G [00:39<00:00, 115MB/s]
# Extracting files...
# Downloading to /tmp/msrvtt/captions/1.archive...
# 100%|██████████| 2.64M/2.64M [00:00<00:00, 53.5MB/s]
# Extracting files...
# Videos: /tmp/msrvtt/videos
# Captions: /tmp/msrvtt/captions
